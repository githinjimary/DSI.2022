# %% [markdown]
# <a href="https://colab.research.google.com/github/githinjimary/DSI.2022/blob/main/module4trial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#standard dependencies
import cv2
import os
import random
from random import randrange
import numpy as np
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/capstone_project')

# %%
pwd
# Out:
# '/content/drive/MyDrive/capstone_project'

# %%
img = cv2.imread('/content/drive/MyDrive/capstone_project/obama3.jpeg')

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
#cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=275x184 at 0x7FF94268C850>

# %%
#cv2.destroyAllWindows()

# %%
#CONVERT RHIS IMAGE TO GRAYSCALE
grayscaled_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(grayscaled_img)
# Out:
# <PIL.Image.Image image mode=L size=275x184 at 0x7FF940D9F710>

# %%
trained_face_data = cv2.CascadeClassifier('/content/drive/MyDrive/capstone_project/haarcascade_frontalface_alt.xml')

# %%
#detect
face_coordinates = trained_face_data.detectMultiScale(grayscaled_img)

# %%
print(face_coordinates)
# Out:
# [[ 56  25  59  59]
#  [178  42  59  59]]

# %%
#rectangle for one image
img = cv2.imread('/content/drive/MyDrive/capstone_project/obama.jpg')
cv2.rectangle(img , (113 , 101) , (320, 308) , (0 , 255 , 0) , 2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x500 at 0x7FF94261C290>

# %%
img = cv2.imread('/content/drive/MyDrive/capstone_project/obama3.jpeg')
for (x , y , w , h) in face_coordinates:
   cv2.rectangle(img , (x , y) , (x+w , y+h) , (0 , 255 , 0) , 2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x184 at 0x7FF951439A90>

# %%
img = cv2.imread('/content/drive/MyDrive/capstone_project/obama3.jpeg')
for (x , y , w , h) in face_coordinates:
   cv2.rectangle(img , (x , y) , (x+w , y+h) , (randrange(256) , randrange(256), randrange(256)) , 3)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x184 at 0x7FF940DA6D10>

# %% [markdown]
# ***VIDEO***

# %%
#TO CAPTURE VIDEO FROM WEBCAM
webcam = cv2.VideoCapture('/content/drive/MyDrive/capstone_project/mixkit-group-of-friends-partying-happily-4640.mp4.crdownload')

# %%
#TO CAPTURE VIDEO FROM WEBCAM
webcam = cv2.VideoCapture(0)

# %%
while True:	
	
	successful_frame_read , frame = webcam.read()

# %%
grayscaled_img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
cv2_imshow(grayscaled_img)
cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-c6ab2c35a596> in <module>()
# ----> 1 grayscaled_img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       2 cv2_imshow(grayscaled_img)
#       3 cv2.waitKey(1)
#
# TypeError: Expected Ptr<cv::UMat> for argument '%s'

# %%
#detect face
face_coordinates = trained_face_data.detectMultiScale(grayscaled_img)

# %%
for (x , y , w , h) in face_coordinates:
			cv2.rectangle(frame , (x , y) , (x+w , y+h) , (0 , 255 , 0) , 5)
   
cv2_imshow(frame)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-047b9e6da60f> in <module>()
#       2                 #       cv2.rectangle(frame , (x , y) , (x+w , y+h) , (0 , 255 , 0) , 5)
#       3
# ----> 4 cv2_imshow(frame)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      20       image.
#      21   """
# ---> 22   a = a.clip(0, 255).astype('uint8')
#      23   # cv2 stores colors as BGR; convert to RGB
#      24   if a.ndim == 3:
#
# AttributeError: 'tuple' object has no attribute 'clip'

# %%
# Image pops up
	cv2.imshow('Name_Your_Frame', frame)
	key = cv2.waitKey(1) # Image will stay until any key is pressed
	
	# To close the web cam
	if key == 81 or key == 113: # ascii code for Q or q
		break

# release the VideoCapture object
# Closes the file and releases all the memory buffers.
webcam.release()
# Out:
#   File "<ipython-input-27-433c265f3bad>", line 2
#     cv2.imshow('Name_Your_Frame', frame)
#     ^
# IndentationError: unexpected indent
